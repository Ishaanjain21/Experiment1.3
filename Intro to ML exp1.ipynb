# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishaanjain21/Experiment1.3/blob/main/Intro%20to%20ML%20exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import statistics as st

# %%
data = [15,28,99,86,88,110,103,87,94,78,77,85,46,35,68]

# %%
print(st.mean(data))
# Out:
# 73.26666666666667

# %%
print(st.mode(data))
# Out:
# 15

# %%
print(st.median(data))
# Out:
# 85

# %%
print(np.sort(data))
# Out:
# [ 15  28  35  46  68  77  78  85  86  87  88  94  99 103 110]

# %%
print(st.stdev(data))
# Out:
# 28.966647487527215

# %%
print(st.variance(data))
# Out:
# 839.0666666666667

# %%
print(np.max(data))
# Out:
# 110

# %%
print(np.min(data))
# Out:
# 15

# %%
print(np.sum(data))
# Out:
# 1099

# %%
print(st.harmonic_mean(data))
# Out:
# 53.76452451942067

# %%
print(np.percentile(data,50))
# Out:
# 85.0

# %%
print(st.median_low(data))
# Out:
# 85

# %%
print(st.median_high(data))
# Out:
# 85

# %%
from scipy.stats import skew
print(skew(data))
# Out:
# -0.7775097482749155

# %%
import scipy
scipy.stats.kurtosis(data)
# Out:
# np.float64(-0.6327948421225051)

# %%
print(st.median_grouped(data,2))
# Out:
# 85.0

# %%
print(st.median_grouped(data,2))
# Out:
# 85.0

# %%
print(st.pvariance(data))
# Out:
# 783.1288888888889

# %%
print(st.pstdev(data))
# Out:
# 27.984440121054572

# %%
print(st.pstdev(data))
# Out:
# 27.984440121054572

# %%
df = pd.read_csv("Exp-1 House Price.csv")

# %%
df.head(5)
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.count()
# Out:
# Area           1259
# BHK            1259
# Bathroom       1257
# Furnishing     1254
# Locality       1259
# Parking        1226
# Price          1259
# Status         1259
# Transaction    1259
# Type           1254
# Per_Sqft       1018
# dtype: int64

# %%
df.sum(numeric_only=True)
# Out:
# Area        1.846264e+06
# BHK         3.521000e+03
# Bathroom    3.213000e+03
# Parking     2.373000e+03
# Price       2.682514e+10
# Per_Sqft    1.597256e+07
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# Area            24300.0
# BHK                10.0
# Bathroom            7.0
# Parking           114.0
# Price       240000000.0
# Per_Sqft       183333.0
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# Area             28.0
# BHK               1.0
# Bathroom          1.0
# Parking           1.0
# Price       1000000.0
# Per_Sqft       1259.0
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# Area        1.568055e+03
# BHK         9.544249e-01
# Bathroom    1.042220e+00
# Parking     6.279212e+00
# Price       2.560115e+07
# Per_Sqft    2.113474e+04
# dtype: float64

# %%
df.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1257.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.556086     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.042220     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1018.000000
# mean    15690.136542
# std     21134.738568
# min      1259.000000
# 25%      6364.000000
# 50%     11291.500000
# 75%     18000.000000
# max    183333.000000

# %%
df.corr(numeric_only=True)
# Out:
#               Area       BHK  Bathroom   Parking     Price  Per_Sqft
# Area      1.000000  0.449438  0.535104 -0.009297  0.580836  0.162832
# BHK       0.449438  1.000000  0.773267 -0.070707  0.571523  0.181540
# Bathroom  0.535104  0.773267  1.000000 -0.032796  0.728108  0.219169
# Parking  -0.009297 -0.070707 -0.032796  1.000000 -0.000448  0.001607
# Price     0.580836  0.571523  0.728108 -0.000448  1.000000  0.322859
# Per_Sqft  0.162832  0.181540  0.219169  0.001607  0.322859  1.000000

# %%
df.skew(numeric_only=True)
# Out:
# Area         8.075156
# BHK          0.530797
# Bathroom     0.833207
# Parking     15.123066
# Price        3.498529
# Per_Sqft     5.336103
# dtype: float64
